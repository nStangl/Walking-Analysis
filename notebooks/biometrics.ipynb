# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)


from biomechanics.functions import (load_pickles, extract_joints, plot_joints_trajectory, 
                       get_step_metrics, get_asymmetry, process_biometrics_df)

# %%
#load all pickle files
model_outputs = load_pickles("../bio_data/pickles/")

tracklets_dict = {}

excluded = ['demo_abnormal-circumduction_gait-frontback']
for video_name, video_results in model_outputs.items():
    print('Current video: ', video_name)
    if video_name not in excluded:
        tracklets_dict[video_name] = extract_joints(video_results)

# %% [markdown]
# The structure of detections_dict we have after the above processing is as follows:
#
# ```python
#     tracklets_dict = {
#
#         #dict for each pickle
#         'pickle_name' : {
#             #dict for each person
#             'person_id' : {
#                 #dict for each joint
#                 'joint_name' : {
#                     #dict for each dimension
#                     'dimension':    List[numpy.float32]     #value for every detected frame
#                 }
#             }
#         }
#     }
# ```

# %%
# gives the whole trajectory of RAnkle for a second person in demo_Athletic_Male
# tracklets_dict['demo_Athletic_Male'][1]['RAnkle'][0]

# %%
tracklet = tracklets_dict['demo_normal-gosia-side']
person_id = 0
joint_list = ['RHeel', 'LHeel']
dim = 0

plot_joints_trajectory(tracklet, person_id, joint_list, dim)

# %% [markdown]
# ## Step metrics

# %%
steps_length, avg_step_length, speed, time, distance = get_step_metrics(tracklets_dict, 'demo_normal-gosia-side', person_id=0, 
                                                                        dim=0, joint='Heel', smoothing=True, _print=True)

# %%
steps_length, avg_step_length, speed, time, distance = get_step_metrics(tracklets_dict, 'demo_Athletic_Male', 
                                                                        person_id=1, dim=0, joint='Heel', smoothing=True, _print=True)

# %% [markdown]
# For now the speed is in meters/timeframes. Needs converting into seconds. I think that every footage is processed in 30fps so this would mean dividing by 30 but we have to make sure.

# %% [markdown]
# Below the same footage from a front view. Well, it's shiet.

# %%
steps_length, avg_step_length, speed, time, distance = get_step_metrics(tracklets_dict, 'demo_Athletic_Male', person_id=0, 
                                                                        dim=2, joint='Heel', smoothing=False)

# %%
steps_length, avg_step_length, speed, time, distance = get_step_metrics(tracklets_dict, 'demo_Athletic_Male', person_id=0, 
                                                                        dim=2, joint='Heel', smoothing=True)

# %% [markdown]
# Why, you would ask?

# %%
tracklet = tracklets_dict['demo_Athletic_Male']
person_id = 0
joint_list = ['RHeel', 'LHeel']
dim = 2

plot_joints_trajectory(tracklet, person_id, joint_list, dim)

# %% [markdown]
# Side-view is the only reasonable angle we can use for step metrics.

# %% [markdown]
# Check for girl video as well below.

# %%
tracklet = tracklets_dict['demo_girl']
person_id = 0
joint_list = ['RHeel', 'LHeel']
dim = 0

plot_joints_trajectory(tracklet, person_id, joint_list, dim)

# %%
steps_length, avg_step_length, speed, time, distance = get_step_metrics(tracklets_dict, 'demo_girl', person_id=0, 
                                                                        dim=0, joint='Heel', smoothing=False)

# %% [markdown]
# ## Asymmetry

# %%
# sideview
asymmetry = get_asymmetry(tracklets_dict, 'demo_Athletic_Male', person_id=1, dim=2, joint='Hip', smoothing=False)

# %%
# frontview
asymmetry = get_asymmetry(tracklets_dict, 'demo_Athletic_Male', person_id=0, dim=0, joint='Hip', smoothing=False)

# %% [markdown]
# ## Biometrics dataframe

# %%
df = process_biometrics_df(folder='pickles')
df.head(30)
# Out:
# Processing video (step_length): demo_abnormal-limping1-front_multiple id: 0
# Processing video (step_length): demo_abnormal-limping1-front_multiple id: 1
# Processing video (step_length): demo_normal-DTU1-front id: 0
# Processing video (step_length): demo_normal-jake-side id: 0
# Processing video (step_length): demo_normal-guy-side id: 0
# Processing video (step_length): demo_normal-karolina-frontback id: 0
# Processing video (step_length): demo_abnormal-hemiplegic_gait4-front id: 0
# Processing video (step_length): demo_normal-athletic_male-front id: 0
# Processing video (step_length): demo_normal-london_man-back id: 0
# Processing video (step_length): demo_abnormal-limping_11-front_multiple id: 0
# Processing video (step_length): demo_abnormal-limping_11-front_multiple id: 1
# Processing video (step_length): demo_normal-gosia-back id: 0
# Processing video (step_length): demo_abnormal-hemiplegic_gait3-front id: 0
# Processing video (step_length): demo_normal-athletic_male-side id: 0
# Processing video (step_length): demo_normal-gosia-side id: 0
# Processing video (step_length): demo_normal-angry_girlfriend-front id: 0
# Processing video (step_length): demo_abnormal-antalgic_gait-front_multiple id: 0
# Processing video (step_length): demo_abnormal-hemiplegic_gait-side id: 0
# Processing video (step_length): demo_normal-holly-front id: 0
# Processing video (step_length): demo_normal-happy_man-side id: 0
# Processing video (step_length): demo_normal-london1-back id: 0
# Processing video (step_length): demo_normal-niklas-back id: 0
# Processing video (step_length): demo_abnormal-limping_2-front_multiple id: 0
# Processing video (step_length): demo_abnormal-limping_2-front_multiple id: 1
# Processing video (step_length): demo_normal-angry_girlfriend-side id: 0
# Processing video (step_length): demo_abnormal-limping_1_4-front_multiple id: 0
# Processing video (step_length): demo_abnormal-limping_1_4-front_multiple id: 1
# Processing video (step_length): demo_abnormal-hemiplegic_gait2-side id: 0
# Processing video (step_length): demo_normal-jake-back id: 0
# Processing video (step_length): demo_normal-DTU1-back id: 0
# Processing video (step_length): demo_normal-holly-back id: 0
# Processing video (step_length): demo_normal-jake-front id: 0
# Processing video (step_length): demo_normal-mafalda-back id: 0
# Processing video (step_length): demo_abnormal-drunk_woman-side_front id: 0
# Processing video (step_length): demo_abnormal-drunk_woman-side_front id: 1
# Processing video (step_length): demo_abnormal-ataxic_gait-front id: 0
# Processing video (step_length): demo_normal-DTU4-back id: 0
# Processing video (step_length): demo_normal-jake-side2 id: 0
# Processing video (step_length): demo_normal-DTU1-side id: 0
# Processing video (step_length): demo_normal-DTU4-side id: 0
# Processing video (step_length): demo_abnormal-limping_4-front_multiple id: 0
# Processing video (step_length): demo_abnormal-limping_4-front_multiple id: 1
# Processing video (step_length): demo_normal-girl-side id: 0
# Processing video (step_length): demo_abnormal-cane1-front_multiple id: 0
# Processing video (step_length): demo_abnormal-cane1-front_multiple id: 1
#    walking_type          video_id  person_id     camera_type  \
# 0      abnormal          limping1          0  front_multiple
# 1      abnormal          limping1          1  front_multiple
# 2        normal              DTU1          0           front
# 3        normal              jake          0            side
# 4        normal               guy          0            side
# 5        normal          karolina          0       frontback
# 6      abnormal  hemiplegic_gait4          0           front
# 7        normal     athletic_male          0           front
# 8        normal        london_man          0            back
# 9      abnormal        limping_11          0  front_multiple
# 10     abnormal        limping_11          1  front_multiple
# 11       normal             gosia          0            back
# 12     abnormal  hemiplegic_gait3          0           front
# 13       normal     athletic_male          0            side
# 14       normal             gosia          0            side
# 15       normal  angry_girlfriend          0           front
# 16     abnormal     antalgic_gait          0  front_multiple
# 17     abnormal   hemiplegic_gait          0            side
# 18       normal             holly          0           front
# 19       normal         happy_man          0            side
# 20       normal           london1          0            back
# 21       normal            niklas          0            back
# 22     abnormal         limping_2          0  front_multiple
# 23     abnormal         limping_2          1  front_multiple
# 24       normal  angry_girlfriend          0            side
# 25     abnormal       limping_1_4          0  front_multiple
# 26     abnormal       limping_1_4          1  front_multiple
# 27     abnormal  hemiplegic_gait2          0            side
# 28       normal              jake          0            back
# 29       normal              DTU1          0            back
#
